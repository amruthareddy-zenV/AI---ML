# %%
# Title : CNN

# Task 1: Cat and Dog Classification
# Use a pre-trained CNN model (e.g., VGG16) to classify images of cats and dogs.
# Observe the model predictions and understand how CNN identifies different features to
# distinguish between cats and dogs.

# Task 2: Digit Recognition with MNIST
# Implement a simple CNN model to classify handwritten digits from the MNIST dataset.
# Evaluate the model's accuracy and discuss how CNN architecture benefits digit
# classification tasks.

# Task 3: Flower Species Classification
# Fine-tune a CNN model using Transfer Learning on a flower dataset.
# Observe how a CNN can be adapted for different image classification tasks beyond
# simple datasets.

# Title : Layers in CNN 
# Convolution Layer

# Task 1: Single Convolutional Layer
# Experiment with adding a single convolutional layer to recognize horizontal and vertical
# edges in an image.
# Visualize the resulting feature maps to understand how edges are detected.

# Task 2: Visualizing Filters
# Use a pre-trained CNN and visualize its filters on early layers, observing patterns like
# edges and textures.
# Discuss the difference in feature complexity as layers deepen.

# Task 3: Custom Kernels
# Manually define custom kernels, such as edge detection or sharpening, apply them to
# an image, and observe changes in the feature map.
# Analyze how specific features are emphasized or diminished.

# Title : Pooling Layer 

# Task 1: Max Pooling vs. Average Pooling
# Apply max pooling and average pooling to a feature map and compare the results.
# Discuss why max pooling is more commonly used in CNNs.

# Task 2: Pooling with Stride Variations
# Modify the stride parameter in pooling operations to observe the effect on feature map
# size.
# Analyze how stride impacts down-sampling and feature abstraction.

# Task 3: Impact on Model Performance
# Train a CNN with and without pooling layers on a small dataset.
# Compare model performance in terms of accuracy and computational cost.

# Title : Fully Connected Layer

# Task 1: Final Classification Layer
# Connect a CNN's convolutional base to a fully connected layer to perform final
# classification.
# Discuss how this layer integrates spatial features for decision-making.

# Task 2: Dimensionality Transition
# Observe how dimensionality changes when transitioning from convolutional to fully
# connected layers.
# Highlight the importance of flattening in this process.

# Task 3: Overfitting Analysis
# Experiment with varying sizes of the fully connected layer.
# Analyze how large fully connected layers can lead to overfitting and implement dropout
# for regularization.

# Title : How CNNs Detect Features in Images
# Edge Detection

# Task 1: Sobel Filters for Edge Detection
# Apply Sobel filters to an input image and visualize the edges detected.
# Experiment with horizontal and vertical edge detection separately.

# Task 2: Edge Detection on Noisy Images
# Add noise to an image and apply edge detection.
# Observe how noise affects edge detection and propose solutions.

# Task 3: Edge Detection Across Channels
# Perform edge detection on different image channels (RGB) separately.
# Discuss differences in edge representation across color channels.

# Title : Feature Maps & Kernels

# Task 1: Visualizing Feature Maps
# Visualize intermediate feature maps within a trained CNN for a given image input.
# Discuss which parts of the image activate specific feature maps and why.

# Task 2: Understanding Kernels
# Analyze different kernel sizes and types, demonstrating their effects, such as blurring or
# sharpening, on an image's feature map.
# Explore how modifying kernel properties alters feature extraction.

# Task 3: Constructing and Applying Custom Kernels
# Manually create custom kernels for specific operations like embossing or edge
# detection.
# Process an image using these kernels to observe and learn about their applied
# transformations.
